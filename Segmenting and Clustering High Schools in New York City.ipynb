# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods - SkoolestHub

# %% [markdown]
# #### - by Arun Sridharan

# %%
# !pip install beautifulsoup4
# !pip install lxml
# !pip install html5lib
# !pip install requests
# !pip install geopy
# !pip install folium

# %% [markdown]
# #  1. Import the list of schools in NYC

# %%
import pandas as pd

# %%
df = pd.read_excel("C:/Users/aruns/Desktop/NYC_School_List.xlsx")
df["Search Address"] = df["School"].astype(str)+', '+df["Borough"]+', '+df["Region"]
df.head()
# Out:
#           Region    Borough  \
# 0  New York City  The Bronx
# 1  New York City  The Bronx
# 2  New York City  The Bronx
# 3  New York City  The Bronx
# 4  New York City  The Bronx
#
#                                               School P.S. Number  \
# 0                Academy for Language and Technology        X365
# 1  Academy for Scholarship and Entrepreneurship: ...        X270
# 2                      Academy of Mount Saint Ursula         NaN
# 3              Adlai E. Stevenson Educational Campus         NaN
# 4  Alfred E. Smith Career and Technical Education...        X600
#
#              Type     Religious Affiliation  \
# 0          Public                       NaN
# 1          Public                       NaN
# 2  Private, girls  Roman Catholic, Ursuline
# 3          Public                       NaN
# 4          Public                       NaN
#
#                                       Search Address
# 0  Academy for Language and Technology, The Bronx...
# ...

# %% [markdown]
# # 2. Get the latitude and the longitude information of the schools

# %%
CLIENT_ID = 'ETGQH3VGLAASMD020YM5WLTSZTQVWZZIGTQFFMEN4FFWO1BB' # your Foursquare ID
CLIENT_SECRET = 'BSL2E0MOO30JHSNHNFQ5VDBEOMWJK3R1ZSYMGHVMPST0B2MN' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: ETGQH3VGLAASMD020YM5WLTSZTQVWZZIGTQFFMEN4FFWO1BB
# CLIENT_SECRET:BSL2E0MOO30JHSNHNFQ5VDBEOMWJK3R1ZSYMGHVMPST0B2MN

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
from geopy.extra.rate_limiter import RateLimiter

geolocator = Nominatim(user_agent="foursquare_agent")
# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# 2- - create location column
df["location"] = df["Search Address"].apply(geocode)
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df["point"] = df["location"].apply(lambda loc: tuple(loc.point) if loc else None)
# 4 - split point column into latitude, longitude and altitude columns
df[["latitude", "longitude","altitude"]] = pd.DataFrame(df["point"].tolist(), index=df.index)
df.head()
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Bronx Center for Science and Mathematics, The Bronx, New York City',), **{}).
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1244, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1290, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1239, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
# ...

# %% [markdown]
# # 3. Data cleaning

# %%
df_clean = df.dropna(subset=["latitude","longitude"])
df_latlong = df_clean.reset_index()
df_latlong.head()
# Out:
#    index         Region    Borough                               School  \
# 0      0  New York City  The Bronx  Academy for Language and Technology
# 1      6  New York City  The Bronx                  Aquinas High School
# 2      9  New York City  The Bronx      Belmont Preparatory High School
# 3     12  New York City  The Bronx             Bronx Academy of Letters
# 4     13  New York City  The Bronx          Bronx Aerospace High School
#
#   P.S. Number            Type Religious Affiliation  \
# 0        X365          Public                   NaN
# 1         NaN  Private, girls        Roman Catholic
# 2        X434          Public                   NaN
# 3        X551          Public                   NaN
# 4        X545          Public                   NaN
#
#                                       Search Address  \
# 0  Academy for Language and Technology, The Bronx...
# 1      Aquinas High School, The Bronx, New York City
# ...

# %% [markdown]
# # 4. Visualization of schools on a map

# %%
import folium

# %%
# create map and display it
ny_map = folium.Map(location=[40.7053837,-74.0157489], zoom_start=10)

# instantiate a feature group for the schools in the dataframe
schools = folium.map.FeatureGroup()

# loop through the schools and add each to the schools feature group
for lat, lng, in zip(df_latlong.latitude, df_latlong.longitude):
    schools.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add incidents to map
ny_map.add_child(schools)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 5. Segmentation of locations using clustering (k-means)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.vq import kmeans2, whiten

# %%
coordinates = df_latlong[["latitude", "longitude"]].values
x, y = kmeans2(whiten(coordinates), 8, iter = 20)
df_cluster = pd.DataFrame({"Cluster":y})

# %%
df_join = df_latlong.join(df_cluster)
df_final = df_join.drop(columns=["index", "Search Address", "location", "point", "altitude"])
df_final.head()
# Out:
#           Region    Borough                               School P.S. Number  \
# 0  New York City  The Bronx  Academy for Language and Technology        X365
# 1  New York City  The Bronx                  Aquinas High School         NaN
# 2  New York City  The Bronx      Belmont Preparatory High School        X434
# 3  New York City  The Bronx             Bronx Academy of Letters        X551
# 4  New York City  The Bronx          Bronx Aerospace High School        X545
#
#              Type Religious Affiliation   latitude  longitude  Cluster
# 0          Public                   NaN  40.849330 -73.915160        1
# 1  Private, girls        Roman Catholic  40.851098 -73.887549        1
# 2          Public                   NaN  40.859383 -73.889174        1
# 3          Public                   NaN  40.813623 -73.926064        0
# 4          Public                   NaN  40.875293 -73.861586        1

# %%
df_Cluster0 = df_final[df_final["Cluster"] == 0]
df_Cluster1 = df_final[df_final["Cluster"] == 1]
df_Cluster2 = df_final[df_final["Cluster"] == 2]
df_Cluster3 = df_final[df_final["Cluster"] == 3]
df_Cluster4 = df_final[df_final["Cluster"] == 4]
df_Cluster5 = df_final[df_final["Cluster"] == 5]
df_Cluster6 = df_final[df_final["Cluster"] == 6]
df_Cluster7 = df_final[df_final["Cluster"] == 7]

# instantiate a feature group for the clusters of schools in the dataframe
cluster0 = folium.map.FeatureGroup()
cluster1 = folium.map.FeatureGroup()
cluster2 = folium.map.FeatureGroup()
cluster3 = folium.map.FeatureGroup()
cluster4 = folium.map.FeatureGroup()
cluster5 = folium.map.FeatureGroup()
cluster6 = folium.map.FeatureGroup()
cluster7 = folium.map.FeatureGroup()

# %%
# loop through the schools and add each to the cluster0 feature group
for lat, lng, in zip(df_Cluster0.latitude, df_Cluster0.longitude):
    cluster0.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='blue'
        )
    )
    
# add incidents to map
ny_map.add_child(cluster0)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# loop through the schools and add each to the cluster1 feature group
for lat, lng, in zip(df_Cluster1.latitude, df_Cluster1.longitude):
    cluster1.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='green'
        )
    )
    
# add incidents to map
ny_map.add_child(cluster1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# loop through the schools and add each to the cluster2 feature group
for lat, lng, in zip(df_Cluster2.latitude, df_Cluster2.longitude):
    cluster2.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='red'
        )
    )
    
# add incidents to map
ny_map.add_child(cluster2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# loop through the schools and add each to the cluster3 feature group
for lat, lng, in zip(df_Cluster3.latitude, df_Cluster3.longitude):
    cluster3.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow'
        )
    )
    
# add incidents to map
ny_map.add_child(cluster3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# loop through the schools and add each to the cluster4 feature group
for lat, lng, in zip(df_Cluster4.latitude, df_Cluster4.longitude):
    cluster4.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='black'
        )
    )
    
# add incidents to map
ny_map.add_child(cluster4)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# loop through the schools and add each to the cluster5 feature group
for lat, lng, in zip(df_Cluster5.latitude, df_Cluster5.longitude):
    cluster5.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='purple'
        )
    )
    
# add incidents to map
ny_map.add_child(cluster5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# loop through the schools and add each to the cluster6 feature group
for lat, lng, in zip(df_Cluster6.latitude, df_Cluster6.longitude):
    cluster6.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='white'
        )
    )
    
# add incidents to map
ny_map.add_child(cluster6)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# loop through the schools and add each to the cluster7 feature group
for lat, lng, in zip(df_Cluster7.latitude, df_Cluster7.longitude):
    cluster7.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='grey'
        )
    )
    
# add incidents to map
ny_map.add_child(cluster7)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 6. Results - Clustered locations of Schools

# %%
ny_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
